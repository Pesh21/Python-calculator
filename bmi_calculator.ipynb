# %%
name1="Abdul"
weight1=70
height1= 6.5

name2="Wendo"
weight2=41
height2= 5.5

name3="Tumaini"
weight3=102
height3= 5.0

def BMI_calculator(name,weight,height):
   BMI= weight/(height**2)
   print("BMI:",round(BMI, 2))
   print(BMI)
   if BMI<25:
    print( name +" "+ "is underweight")
   else:
    print(name +" " +" is overweight")
result1= BMI_calculator(name1,weight1,height1)
result2= BMI_calculator(name2,weight2,height2)
result3= BMI_calculator(name3,weight3,height3)
# Out:
# BMI: 1.66
# 1.6568047337278107
# Abdul is underweight
# BMI: 1.36
# 1.3553719008264462
# Wendo is underweight
# BMI: 4.08
# 4.08
# Tumaini is underweight
