# %%
name1="Abdul"
weight1=70
height1= 6.5

name2="Wendo"
weight2=41
height2= 5.5

name3="Tumaini"
weight3=102
height3= 5.0

def BMI_calculator(name,weight,height):
   BMI= weight/(height**2)
   print("BMI: ")
   print(BMI)
   if BMI<25:
    print( name + "is underweight")
   else:
    print(name +" is overweight")
x= BMI_calculator(name1,weight1,height1)
= BMI_calculator(name2,weight2,height2)
print(name3,weight3,height3)
# Out:
# Abdul 70 6.5
# Wendo 41 5.5
# Tumaini 102 5.0
